# %% [markdown]
# ## Genre prediction of NHK shows using BERT

# %% [markdown]
# I have done clustering of NHK shows using TF-IDF and K-Means. Now I am going to predict show's genre using BERT! <br>
# Note: This code was taken from the article "Multi Class Text Classification With Deep Learning Using BERT" by Susan Li at <br>
# https://towardsdatascience.com/multi-class-text-classification-with-deep-learning-using-bert-b59ca2f5c613

# %%
# !pip install transformers
# !pip install fugashi
# !pip install ipadic
# Out:
# Requirement already satisfied: transformers in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (4.20.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from transformers) (0.8.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from transformers) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from transformers) (2020.10.15)
# Requirement already satisfied: requests in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from transformers) (0.12.1)
# Requirement already satisfied: numpy>=1.17 in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from transformers) (1.19.2)
# Requirement already satisfied: filelock in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2.0.12)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Users/mihohunter/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: fugashi in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (1.1.2)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Users/mihohunter/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: ipadic in /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages (1.0.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Users/mihohunter/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import random
import numpy as np

import torch
from tqdm import tqdm
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from torch.utils.data import TensorDataset

import transformers
from transformers import BertJapaneseTokenizer
from transformers import BertForSequenceClassification
from transformers import AdamW, get_linear_schedule_with_warmup

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mhunter13/NLP_final_project/main/nhk_0626_0703_0710.csv")

# %%
df['genre1'] = df['genres'].str[2:4] # new "genre1" column with just one genre code
label_dict = {'00':'ニュース/報道','01':'スポーツ','02':'情報/ワイドショー','03':'ドラマ','04':'音楽','05':'バラエティ','06':'映画','07':'アニメ/特撮','08':'ドキュメンタリー/教養','09':'劇場・公演','10':'趣味/教育','11':'福祉','15':'その他'} 
# create label dict
df['genre_name'] = df.genre1.replace(label_dict) # creating label column with category names

# %%
df.genre1.unique()
# Out:
# array(['08', '11', '04', '00', '03', '02', '05', '01', '10', '09', '07',
#        '15', '06', ''], dtype=object)

# %%
df.drop(df[df['genre1']==''].index, inplace=True)

# %%
df = df.drop(df.iloc[:, 9:-3],axis=1)
df['all_content'] = df['title'] + df['subtitle'].fillna('')
df.head(2)
# Out:
#               id  event_id                 start_time  \
# 0  2022062633674     33674  2022-06-26T04:13:00+09:00
# 1  2022062633676     33676  2022-06-26T04:15:00+09:00
#
#                     end_time                            title  \
# 0  2022-06-26T04:15:00+09:00                        インターミッション
# 1  2022-06-26T04:20:00+09:00  ５分でみんなの手話「祖父と祖母と両親ときょうだいが４人なんだ」
#
#                                             subtitle  \
# 0                                                NaN
# 1  ２０２１年度に放送したＥテレ「みんなの手話」から１つのキーフレーズをピックアップ。「祖父と祖...
#
#                                              content  \
# 0                                                NaN
# 1  ２０２１年度に放送したＥテレ「みんなの手話」から１つのキーフレーズをピックアップ。「祖父と祖...
#
#                                   act    genres  service.logo_l.height genre1  \
# 0                                 NaN  ['0815']                    200     08
# 1  【出演】三宅健，森田明，那須善子，那須映里，寺澤英弥，【声】黒柳徹子  ['1104']                    200     11
#
#     genre_name                                        all_content
# 0  ドキュメンタリー/教養                                          インターミッション
# 1           福祉  ５分でみんなの手話「祖父と祖母と両親ときょうだいが４人なんだ」２０２１年度に放送したＥテレ「...

# %%
# input_key = "all_content"
# label_key = "genre_name"

# %%
## remove duplicates
print(df.shape)
df = df.drop_duplicates("event_id").reset_index(drop=True)
print(df.shape)
df = df[['all_content', 'genre_name']]
# Out:
# (9592, 13)
# (7454, 13)

# %%
df['genre_name'].value_counts()
# Out:
# ニュース/報道        2236
# 趣味/教育          1931
# ドキュメンタリー/教養    1007
# 音楽              704
# 情報/ワイドショー       442
# スポーツ            296
# ドラマ             245
# バラエティ           227
# アニメ/特撮          153
# その他             117
# 福祉               58
# 劇場・公演            24
# 映画               14
# Name: genre_name, dtype: int64

# %%
possible_labels = df['genre_name'].unique()

label_dict = {}
for index, possible_label in enumerate(possible_labels):
    label_dict[possible_label] = index

# %%
df['label'] = df['genre_name'].replace(label_dict)

# %%
df.head()
# Out:
#                                          all_content   genre_name  label
# 0                                          インターミッション  ドキュメンタリー/教養      0
# 1  ５分でみんなの手話「祖父と祖母と両親ときょうだいが４人なんだ」２０２１年度に放送したＥテレ「...           福祉      1
# 2  名曲アルバム「ソルヴェイグの歌」グリーグ作曲「ソルヴェイグの歌」（ソプラノ）天羽明惠，（ピア...           音楽      2
# 3                  みんなのうた「くじらのあくび」「くじらのあくび」うた：ザ・ジェイド           音楽      2
# 4  イッピン・選「色彩ゆたかに　あざやかに」「西の西陣・東の桐生」と並び称された織物の産地、群馬...  ドキュメンタリー/教養      0

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(df.index.values, 
                                                  df.label.values, 
                                                  test_size=0.2, 
                                                  random_state=42, 
                                                  stratify=df.label.values)

# %%
df['data_type'] = ['not_set']*df.shape[0]

df.loc[X_train, 'data_type'] = 'train'
df.loc[X_val, 'data_type'] = 'val'

# %%
tokenizer = BertJapaneseTokenizer.from_pretrained('cl-tohoku/bert-base-japanese')

# %%
encoded_data_train = tokenizer.batch_encode_plus(
    df[df.data_type=='train']['all_content'].values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=128, 
    return_tensors='pt',
    truncation=True
)

encoded_data_val = tokenizer.batch_encode_plus(
    df[df.data_type=='val']['all_content'].values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=128, 
    return_tensors='pt',
    truncation=True
)

input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df[df.data_type=='train'].label.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
labels_val = torch.tensor(df[df.data_type=='val'].label.values)
# Out:
# /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:2301: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, labels_val)

# %%
len(label_dict)
# Out:
# 13

# %%
model = BertForSequenceClassification.from_pretrained("cl-tohoku/bert-base-japanese-v2",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# Some weights of the model checkpoint at cl-tohoku/bert-base-japanese-v2 were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cl-tohoku/bert-base-japanese-v2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
batch_size = 32

dataloader_train = DataLoader(dataset_train, 
                              sampler=RandomSampler(dataset_train), 
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_val, 
                                   sampler=SequentialSampler(dataset_val), 
                                   batch_size=batch_size)

# %%
optimizer = AdamW(model.parameters(),
                  lr=1e-5, 
                  eps=1e-8)
# Out:
# /Users/mihohunter/opt/anaconda3/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
epochs = 5

scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)

# %%
from sklearn.metrics import f1_score

def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in label_dict.items()}
    
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

# %%
seed_val = 17
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
print(device)
# Out:
# cpu

# %%
def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:

        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals

# %%
# training

for epoch in tqdm(range(1, epochs+1)):

    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)

        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }
       
        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))}, refresh=False)
         
        
    torch.save(model.state_dict(), f'data_volume/finetuned_BERT_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    val_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {val_loss}')
    tqdm.write(f'F1 Score (Weighted): {val_f1}')
    tqdm.write("------")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/187 [00:00<?, ?it/s]
# Epoch 1:   1%|          | 1/187 [00:55<2:50:44, 55.08s/it, training_loss=0.831]
# Epoch 1:   1%|          | 2/187 [01:50<2:50:30, 55.30s/it, training_loss=0.802]
# Epoch 1:   2%|▏         | 3/187 [02:46<2:49:53, 55.40s/it, training_loss=0.777]
# Epoch 1:   2%|▏         | 4/187 [03:41<2:49:06, 55.44s/it, training_loss=0.753]
# Epoch 1:   3%|▎         | 5/187 [04:36<2:48:09, 55.44s/it, training_loss=0.730]
# Epoch 1:   3%|▎         | 6/187 [05:32<2:47:10, 55.42s/it, training_loss=0.725]
# Epoch 1:   4%|▎         | 7/187 [06:27<2:46:16, 55.43s/it, training_loss=0.690]
# Epoch 1:   4%|▍         | 8/187 [07:23<2:45:26, 55.46s/it, training_loss=0.679]
# Epoch 1:   5%|▍         | 9/187 [08:18<2:44:36, 55.48s/it, training_loss=0.680]
# Epoch 1:   5%|▌         | 10/187 [09:14<2:43:39, 55.48s/it, training_loss=0.627]
# Epoch 1:   6%|▌         | 11/187 [10:09<2:42:50, 55.51s/it, training_loss=0.686]
# Epoch 1:   6%|▋         | 12/187 [11:05<2:42:08, 55.59s/it, training_loss=0.593]
# Epoch 1:   7%|▋         | 13/187 [12:01<2:41:05, 55.55s/it, training_loss=0.655]
# Epoch 1:   7%|▋         | 14/187 [12:56<2:40:01, 55.50s/it, training_loss=0.622]
# Epoch 1:   8%|▊         | 15/187 [13:51<2:38:50, 55.41s/it, training_loss=0.587]
# Epoch 1:   9%|▊         | 16/187 [14:46<2:37:45, 55.35s/it, training_loss=0.652]
# Epoch 1:   9%|▉         | 17/187 [15:42<2:37:00, 55.42s/it, training_loss=0.574]
# Epoch 1:  10%|▉         | 18/187 [16:45<2:42:42, 57.77s/it, training_loss=0.683]
# Epoch 1:  10%|█         | 19/187 [17:41<2:40:25, 57.29s/it, training_loss=0.600]
# Epoch 1:  11%|█         | 20/187 [18:37<2:37:59, 56.76s/it, training_loss=0.643]
# Epoch 1:  11%|█         | 21/187 [19:33<2:36:49, 56.68s/it, training_loss=0.481]
# Epoch 1:  12%|█▏        | 22/187 [20:30<2:35:45, 56.64s/it, training_loss=0.581]
# Epoch 1:  12%|█▏        | 23/187 [21:27<2:34:52, 56.66s/it, training_loss=0.689]
# Epoch 1:  13%|█▎        | 24/187 [22:23<2:33:22, 56.45s/it, training_loss=0.623]
# Epoch 1:  13%|█▎        | 25/187 [23:19<2:32:23, 56.44s/it, training_loss=0.605]
# Epoch 1:  14%|█▍        | 26/187 [24:16<2:31:26, 56.44s/it, training_loss=0.632]
# Epoch 1:  76%|███████▋  | 143/187 [2:37:17<41:31, 56.62s/it, training_loss=0.403]
# Epoch 1:  77%|███████▋  | 144/187 [2:38:13<40:25, 56.41s/it, training_loss=0.260]
# Epoch 1:  78%|███████▊  | 145/187 [2:39:10<39:37, 56.61s/it, training_loss=0.399]
# Epoch 1:  78%|███████▊  | 146/187 [2:40:06<38:34, 56.44s/it, training_loss=0.362]
# Epoch 1:  79%|███████▊  | 147/187 [2:41:02<37:27, 56.20s/it, training_loss=0.270]
# Epoch 1:  79%|███████▉  | 148/187 [2:41:59<36:47, 56.61s/it, training_loss=0.286]
# Epoch 1:  80%|███████▉  | 149/187 [2:42:57<36:06, 57.01s/it, training_loss=0.417]
# Epoch 1:  80%|████████  | 150/187 [2:43:55<35:18, 57.26s/it, training_loss=0.303]
# Epoch 1:  81%|████████  | 151/187 [2:44:52<34:17, 57.15s/it, training_loss=0.460]
# Epoch 1:  81%|████████▏ | 152/187 [2:45:49<33:20, 57.15s/it, training_loss=0.323]
# Epoch 1:  82%|████████▏ | 153/187 [2:46:47<32:32, 57.43s/it, training_loss=0.349]
# Epoch 1:  82%|████████▏ | 154/187 [2:47:44<31:29, 57.27s/it, training_loss=0.374]
# Epoch 1:  83%|████████▎ | 155/187 [2:48:41<30:26, 57.08s/it, training_loss=0.281]
# Epoch 1:  83%|████████▎ | 156/187 [2:49:37<29:23, 56.89s/it, training_loss=0.400]
# Epoch 1:  84%|████████▍ | 157/187 [2:50:35<28:29, 56.99s/it, training_loss=0.309]
# Epoch 1:  84%|████████▍ | 158/187 [2:51:32<27:40, 57.25s/it, training_loss=0.357]
# Epoch 1:  85%|████████▌ | 159/187 [2:52:29<26:39, 57.14s/it, training_loss=0.367]
# Epoch 1:  86%|████████▌ | 160/187 [2:53:26<25:41, 57.09s/it, training_loss=0.327]
# Epoch 1:  86%|████████▌ | 161/187 [2:54:26<25:01, 57.74s/it, training_loss=0.279]
# Epoch 1:  87%|████████▋ | 162/187 [2:55:24<24:05, 57.83s/it, training_loss=0.344]
# Epoch 1:  87%|████████▋ | 163/187 [2:56:21<23:01, 57.57s/it, training_loss=0.306]
# Epoch 1:  88%|████████▊ | 164/187 [2:57:17<21:53, 57.12s/it, training_loss=0.319]
# Epoch 1:  88%|████████▊ | 165/187 [2:58:14<21:00, 57.31s/it, training_loss=0.246]
# Epoch 1:  89%|████████▉ | 166/187 [2:59:10<19:54, 56.90s/it, training_loss=0.316]
# Epoch 1:  89%|████████▉ | 167/187 [3:00:08<19:03, 57.18s/it, training_loss=0.370]
# Epoch 1:  90%|████████▉ | 168/187 [3:01:05<18:02, 56.98s/it, training_loss=0.251]
# Epoch 1:  90%|█████████ | 169/187 [3:02:01<17:03, 56.87s/it, training_loss=0.322]
# Epoch 1:  91%|█████████ | 170/187 [3:02:57<16:02, 56.65s/it, training_loss=0.417]
# Epoch 1:  91%|█████████▏| 171/187 [3:03:54<15:08, 56.77s/it, training_loss=0.286]
# Epoch 1:  92%|█████████▏| 172/187 [3:04:50<14:08, 56.53s/it, training_loss=0.301]
# Epoch 1:  93%|█████████▎| 173/187 [3:05:46<13:08, 56.31s/it, training_loss=0.312]
# Epoch 1:  93%|█████████▎| 174/187 [3:06:43<12:13, 56.39s/it, training_loss=0.399]
# Epoch 1:  94%|█████████▎| 175/187 [3:07:39<11:16, 56.38s/it, training_loss=0.231]
# Epoch 1:  94%|█████████▍| 176/187 [3:08:35<10:17, 56.12s/it, training_loss=0.508]
# Epoch 1:  95%|█████████▍| 177/187 [3:09:30<09:19, 55.94s/it, training_loss=0.412]
# Epoch 1:  95%|█████████▌| 178/187 [3:10:25<08:21, 55.73s/it, training_loss=0.355]
# Epoch 1:  96%|█████████▌| 179/187 [3:11:21<07:25, 55.70s/it, training_loss=0.284]
# Epoch 1:  96%|█████████▋| 180/187 [3:12:16<06:29, 55.60s/it, training_loss=0.317]
# Epoch 1:  97%|█████████▋| 181/187 [3:13:13<05:35, 55.89s/it, training_loss=0.322]
# Epoch 1:  97%|█████████▋| 182/187 [3:14:10<04:41, 56.23s/it, training_loss=0.302]
# Epoch 1:  98%|█████████▊| 183/187 [3:15:07<03:45, 56.44s/it, training_loss=0.254]
# Epoch 1:  98%|█████████▊| 184/187 [3:16:04<02:49, 56.61s/it, training_loss=0.258]
# Epoch 1:  99%|█████████▉| 185/187 [3:17:01<01:53, 56.68s/it, training_loss=0.422]
# Epoch 1:  99%|█████████▉| 186/187 [3:17:57<00:56, 56.60s/it, training_loss=0.309]
# Epoch 1: 100%|██████████| 187/187 [3:18:16<00:00, 45.23s/it, training_loss=0.259]
#   0%|          | 0/5 [3:18:16<?, ?it/s]
# Epoch 1
# Training loss: 1.372821256119937
#  20%|██        | 1/5 [3:32:08<14:08:33, 12728.34s/it]
# Validation loss: 0.8695322579525887
# F1 Score (Weighted): 0.7100091957230805
# ------
# Epoch 2:   0%|          | 0/187 [00:00<?, ?it/s]
# Epoch 2:   1%|          | 1/187 [00:58<3:00:12, 58.13s/it, training_loss=0.198]
# Epoch 2:   1%|          | 2/187 [01:54<2:56:55, 57.38s/it, training_loss=0.203]
# Epoch 2:   2%|▏         | 3/187 [02:51<2:54:59, 57.06s/it, training_loss=0.334]
# Epoch 2:   2%|▏         | 4/187 [03:48<2:53:47, 56.98s/it, training_loss=0.376]
# Epoch 2:   3%|▎         | 5/187 [04:45<2:52:21, 56.82s/it, training_loss=0.244]
# Epoch 2:   3%|▎         | 6/187 [05:41<2:51:13, 56.76s/it, training_loss=0.231]
# Epoch 2:   4%|▎         | 7/187 [06:38<2:50:43, 56.91s/it, training_loss=0.289]
# Epoch 2:   4%|▍         | 8/187 [07:37<2:51:08, 57.37s/it, training_loss=0.356]
# Epoch 2:   5%|▍         | 9/187 [08:34<2:49:59, 57.30s/it, training_loss=0.217]
# Epoch 2:   5%|▌         | 10/187 [09:32<2:49:33, 57.48s/it, training_loss=0.241]
# Epoch 2:   6%|▌         | 11/187 [10:29<2:48:22, 57.40s/it, training_loss=0.334]
# Epoch 2:   6%|▋         | 12/187 [11:28<2:48:51, 57.90s/it, training_loss=0.270]
# Epoch 2:   7%|▋         | 13/187 [12:26<2:47:52, 57.89s/it, training_loss=0.315]
# Epoch 2:   7%|▋         | 14/187 [13:23<2:46:09, 57.63s/it, training_loss=0.387]
# Epoch 2:   8%|▊         | 15/187 [14:20<2:45:04, 57.59s/it, training_loss=0.242]
# Epoch 2:   9%|▊         | 16/187 [15:18<2:43:47, 57.47s/it, training_loss=0.355]
# Epoch 2:   9%|▉         | 17/187 [16:15<2:42:26, 57.33s/it, training_loss=0.300]
# Epoch 2:  10%|▉         | 18/187 [17:12<2:41:11, 57.23s/it, training_loss=0.320]
# Epoch 2:  10%|█         | 19/187 [18:08<2:39:50, 57.09s/it, training_loss=0.258]
# Epoch 2:  11%|█         | 20/187 [19:07<2:39:48, 57.42s/it, training_loss=0.281]
# Epoch 2:  11%|█         | 21/187 [20:05<2:39:27, 57.63s/it, training_loss=0.411]
# Epoch 2:  12%|█▏        | 22/187 [21:02<2:38:01, 57.46s/it, training_loss=0.300]
# Epoch 2:  12%|█▏        | 23/187 [21:58<2:36:05, 57.11s/it, training_loss=0.261]
# Epoch 2:  13%|█▎        | 24/187 [22:55<2:34:40, 56.94s/it, training_loss=0.219]
# Epoch 2:  13%|█▎        | 25/187 [23:51<2:33:32, 56.87s/it, training_loss=0.303]
# Epoch 2:  14%|█▍        | 26/187 [24:49<2:33:01, 57.03s/it, training_loss=0.241]
# Epoch 2:  14%|█▍        | 27/187 [25:45<2:31:42, 56.89s/it, training_loss=0.332]
# Epoch 2:  15%|█▍        | 28/187 [26:42<2:30:26, 56.77s/it, training_loss=0.304]
# Epoch 2:  16%|█▌        | 29/187 [27:38<2:29:20, 56.72s/it, training_loss=0.237]
# Epoch 2:  16%|█▌        | 30/187 [28:35<2:28:27, 56.74s/it, training_loss=0.233]
# Epoch 2:  17%|█▋        | 31/187 [29:31<2:27:10, 56.61s/it, training_loss=0.353]
# Epoch 2:  17%|█▋        | 32/187 [30:28<2:26:19, 56.64s/it, training_loss=0.204]
# Epoch 2:  18%|█▊        | 33/187 [31:27<2:26:56, 57.25s/it, training_loss=0.356]
# Epoch 2:  18%|█▊        | 34/187 [32:26<2:27:17, 57.76s/it, training_loss=0.339]
# Epoch 2:  19%|█▊        | 35/187 [33:23<2:26:15, 57.73s/it, training_loss=0.189]
# Epoch 2:  19%|█▉        | 36/187 [34:21<2:25:19, 57.75s/it, training_loss=0.357]
# Epoch 2:  20%|█▉        | 37/187 [35:18<2:23:58, 57.59s/it, training_loss=0.255]
# Epoch 2:  20%|██        | 38/187 [36:15<2:22:27, 57.37s/it, training_loss=0.252]
# Epoch 2:  21%|██        | 39/187 [37:13<2:21:33, 57.39s/it, training_loss=0.433]
# Epoch 2:  21%|██▏       | 40/187 [38:10<2:20:39, 57.41s/it, training_loss=0.331]
# Epoch 2:  22%|██▏       | 41/187 [39:07<2:19:35, 57.37s/it, training_loss=0.242]
# Epoch 2:  53%|█████▎    | 100/187 [1:34:16<1:20:42, 55.66s/it, training_loss=0.260]
# Epoch 2:  54%|█████▍    | 101/187 [1:35:11<1:19:41, 55.60s/it, training_loss=0.363]
# Epoch 2:  55%|█████▍    | 102/187 [1:36:07<1:18:38, 55.51s/it, training_loss=0.261]
# Epoch 2:  55%|█████▌    | 103/187 [1:37:02<1:17:37, 55.45s/it, training_loss=0.274]
# Epoch 2:  56%|█████▌    | 104/187 [1:37:58<1:17:02, 55.70s/it, training_loss=0.293]
# Epoch 2:  56%|█████▌    | 105/187 [1:38:54<1:16:06, 55.69s/it, training_loss=0.186]
# Epoch 2:  57%|█████▋    | 106/187 [1:39:49<1:15:06, 55.63s/it, training_loss=0.289]
# Epoch 2:  57%|█████▋    | 107/187 [1:40:46<1:14:23, 55.79s/it, training_loss=0.190]
# Epoch 2:  58%|█████▊    | 108/187 [1:41:41<1:13:20, 55.70s/it, training_loss=0.248]
# Epoch 2:  58%|█████▊    | 109/187 [1:42:37<1:12:27, 55.73s/it, training_loss=0.268]
# Epoch 2:  59%|█████▉    | 110/187 [1:43:33<1:11:29, 55.71s/it, training_loss=0.272]
# Epoch 2:  59%|█████▉    | 111/187 [1:44:28<1:10:29, 55.65s/it, training_loss=0.329]
# Epoch 2:  60%|█████▉    | 112/187 [1:45:27<1:10:57, 56.76s/it, training_loss=0.147]
# Epoch 2:  60%|██████    | 113/187 [1:46:25<1:10:18, 57.01s/it, training_loss=0.267]
# Epoch 2:  61%|██████    | 114/187 [1:47:21<1:08:51, 56.59s/it, training_loss=0.263]
# Epoch 2:  61%|██████▏   | 115/187 [1:48:16<1:07:33, 56.30s/it, training_loss=0.219]
# Epoch 2:  62%|██████▏   | 116/187 [1:49:13<1:06:36, 56.28s/it, training_loss=0.241]
# Epoch 2:  63%|██████▎   | 117/187 [1:50:08<1:05:27, 56.10s/it, training_loss=0.181]
# Epoch 2:  63%|██████▎   | 118/187 [1:51:04<1:04:17, 55.91s/it, training_loss=0.324]
# Epoch 2:  64%|██████▎   | 119/187 [1:51:59<1:03:17, 55.85s/it, training_loss=0.284]
# Epoch 2:  64%|██████▍   | 120/187 [1:52:55<1:02:14, 55.75s/it, training_loss=0.208]
# Epoch 2:  65%|██████▍   | 121/187 [1:53:51<1:01:18, 55.74s/it, training_loss=0.157]
# Epoch 2:  65%|██████▌   | 122/187 [1:54:46<1:00:22, 55.73s/it, training_loss=0.197]
# Epoch 2:  66%|██████▌   | 123/187 [1:55:42<59:32, 55.81s/it, training_loss=0.278]
# Epoch 2:  66%|██████▋   | 124/187 [1:56:38<58:36, 55.82s/it, training_loss=0.204]
# Epoch 2:  67%|██████▋   | 125/187 [1:57:34<57:34, 55.72s/it, training_loss=0.299]
# Epoch 2:  67%|██████▋   | 126/187 [1:58:30<56:45, 55.83s/it, training_loss=0.198]
# Epoch 2:  68%|██████▊   | 127/187 [1:59:25<55:41, 55.69s/it, training_loss=0.249]
# Epoch 2:  68%|██████▊   | 128/187 [2:00:21<54:47, 55.72s/it, training_loss=0.290]
# Epoch 2:  69%|██████▉   | 129/187 [2:01:17<53:50, 55.71s/it, training_loss=0.283]
# Epoch 2:  70%|██████▉   | 130/187 [2:02:12<52:53, 55.67s/it, training_loss=0.170]
# Epoch 2:  70%|███████   | 131/187 [2:03:07<51:50, 55.54s/it, training_loss=0.261]
# Epoch 2:  71%|███████   | 132/187 [2:04:03<50:49, 55.44s/it, training_loss=0.228]
# Epoch 2:  71%|███████   | 133/187 [2:04:58<49:52, 55.41s/it, training_loss=0.243]
# Epoch 2:  72%|███████▏  | 134/187 [2:05:53<48:56, 55.40s/it, training_loss=0.215]
# Epoch 2:  72%|███████▏  | 135/187 [2:06:49<47:59, 55.38s/it, training_loss=0.179]
# Epoch 2:  73%|███████▎  | 136/187 [2:07:44<47:04, 55.39s/it, training_loss=0.244]
# Epoch 2:  73%|███████▎  | 137/187 [2:08:39<46:08, 55.36s/it, training_loss=0.291]
# Epoch 2:  74%|███████▍  | 138/187 [2:09:35<45:12, 55.35s/it, training_loss=0.192]
# Epoch 2:  74%|███████▍  | 139/187 [2:10:30<44:14, 55.31s/it, training_loss=0.157]
# Epoch 2:  75%|███████▍  | 140/187 [2:11:26<43:30, 55.55s/it, training_loss=0.154]
# Epoch 2:  75%|███████▌  | 141/187 [2:12:22<42:36, 55.58s/it, training_loss=0.330]
# Epoch 2:  76%|███████▌  | 142/187 [2:13:17<41:37, 55.50s/it, training_loss=0.314]
# Epoch 2:  76%|███████▋  | 143/187 [2:14:12<40:38, 55.43s/it, training_loss=0.188]
# Epoch 2:  77%|███████▋  | 144/187 [2:15:08<39:41, 55.39s/it, training_loss=0.268]
# Epoch 2:  78%|███████▊  | 145/187 [2:16:03<38:44, 55.34s/it, training_loss=0.204]
# Epoch 2:  78%|███████▊  | 146/187 [2:16:58<37:50, 55.37s/it, training_loss=0.208]
# Epoch 2:  79%|███████▊  | 147/187 [2:17:54<36:54, 55.37s/it, training_loss=0.231]
# Epoch 2:  79%|███████▉  | 148/187 [2:18:49<35:59, 55.38s/it, training_loss=0.179]
# Epoch 2:  80%|███████▉  | 149/187 [2:19:44<35:02, 55.33s/it, training_loss=0.231]
# Epoch 2:  80%|████████  | 150/187 [2:20:40<34:07, 55.35s/it, training_loss=0.252]
# Epoch 2:  81%|████████  | 151/187 [2:21:35<33:13, 55.37s/it, training_loss=0.208]
# Epoch 2:  81%|████████▏ | 152/187 [2:22:30<32:15, 55.30s/it, training_loss=0.137]
# Epoch 2:  82%|████████▏ | 153/187 [2:23:26<31:20, 55.32s/it, training_loss=0.259]
# Epoch 2:  82%|████████▏ | 154/187 [2:24:21<30:25, 55.31s/it, training_loss=0.220]
# Epoch 2:  83%|████████▎ | 155/187 [2:25:16<29:30, 55.34s/it, training_loss=0.246]
# Epoch 2:  83%|████████▎ | 156/187 [2:26:12<28:35, 55.33s/it, training_loss=0.183]
# Epoch 2:  84%|████████▍ | 157/187 [2:27:07<27:38, 55.30s/it, training_loss=0.185]
# Epoch 2:  84%|████████▍ | 158/187 [2:28:02<26:42, 55.27s/it, training_loss=0.253]
# Epoch 2:  85%|████████▌ | 159/187 [2:28:57<25:48, 55.31s/it, training_loss=0.240]
# Epoch 2:  86%|████████▌ | 160/187 [2:29:53<24:52, 55.28s/it, training_loss=0.267]
# Epoch 2:  86%|████████▌ | 161/187 [2:30:48<23:56, 55.26s/it, training_loss=0.192]
# Epoch 2:  87%|████████▋ | 162/187 [2:31:43<23:01, 55.28s/it, training_loss=0.162]
# Epoch 2:  87%|████████▋ | 163/187 [2:32:39<22:07, 55.33s/it, training_loss=0.238]
# Epoch 2:  88%|████████▊ | 164/187 [2:33:34<21:12, 55.33s/it, training_loss=0.232]
# Epoch 2:  88%|████████▊ | 165/187 [2:34:29<20:16, 55.32s/it, training_loss=0.186]
# Epoch 2:  89%|████████▉ | 166/187 [2:35:24<19:21, 55.30s/it, training_loss=0.210]
# Epoch 2:  89%|████████▉ | 167/187 [2:36:20<18:26, 55.34s/it, training_loss=0.186]
# Epoch 2:  90%|████████▉ | 168/187 [2:37:15<17:31, 55.33s/it, training_loss=0.348]
# Epoch 2:  90%|█████████ | 169/187 [2:38:11<16:36, 55.38s/it, training_loss=0.265]
# Epoch 2:  91%|█████████ | 170/187 [2:39:06<15:41, 55.37s/it, training_loss=0.292]
# Epoch 2:  91%|█████████▏| 171/187 [2:40:02<14:46, 55.42s/it, training_loss=0.275]
# Epoch 2:  92%|█████████▏| 172/187 [2:40:57<13:50, 55.37s/it, training_loss=0.166]
# Epoch 2:  93%|█████████▎| 173/187 [2:41:52<12:54, 55.33s/it, training_loss=0.197]
# Epoch 2:  93%|█████████▎| 174/187 [2:42:47<11:58, 55.28s/it, training_loss=0.276]
# Epoch 2:  94%|█████████▎| 175/187 [2:43:43<11:03, 55.33s/it, training_loss=0.137]
# Epoch 2:  94%|█████████▍| 176/187 [2:44:38<10:08, 55.31s/it, training_loss=0.282]
# Epoch 2:  95%|█████████▍| 177/187 [2:45:33<09:12, 55.27s/it, training_loss=0.228]
# Epoch 2:  95%|█████████▌| 178/187 [2:46:28<08:17, 55.29s/it, training_loss=0.150]
# Epoch 2:  96%|█████████▌| 179/187 [2:47:24<07:22, 55.29s/it, training_loss=0.192]
# Epoch 2:  96%|█████████▋| 180/187 [2:48:19<06:27, 55.30s/it, training_loss=0.169]
# Epoch 2:  97%|█████████▋| 181/187 [2:49:14<05:31, 55.29s/it, training_loss=0.219]
# Epoch 2:  97%|█████████▋| 182/187 [2:50:10<04:36, 55.35s/it, training_loss=0.256]
# Epoch 2:  98%|█████████▊| 183/187 [2:51:05<03:41, 55.35s/it, training_loss=0.155]
# Epoch 2:  98%|█████████▊| 184/187 [2:52:00<02:46, 55.34s/it, training_loss=0.201]
# Epoch 2:  99%|█████████▉| 185/187 [2:52:56<01:50, 55.33s/it, training_loss=0.188]
# Epoch 2:  99%|█████████▉| 186/187 [2:53:51<00:55, 55.29s/it, training_loss=0.244]
# Epoch 2: 100%|██████████| 187/187 [2:54:10<00:00, 44.33s/it, training_loss=0.311]
#  20%|██        | 1/5 [6:26:18<14:08:33, 12728.34s/it]
# Epoch 2
# Training loss: 0.7701135443493644
#  40%|████      | 2/5 [6:39:49<9:53:16, 11865.53s/it]
# Validation loss: 0.6126995635159472
# F1 Score (Weighted): 0.8284324453603168
# ------
# Epoch 3:   0%|          | 0/187 [00:00<?, ?it/s]
# Epoch 3:   1%|          | 1/187 [00:56<2:54:09, 56.18s/it, training_loss=0.219]
# Epoch 3:   1%|          | 2/187 [01:51<2:52:10, 55.84s/it, training_loss=0.180]
# Epoch 3:   2%|▏         | 3/187 [02:47<2:50:24, 55.57s/it, training_loss=0.223]
# Epoch 3:   2%|▏         | 4/187 [03:42<2:49:28, 55.57s/it, training_loss=0.151]
# Epoch 3:   3%|▎         | 5/187 [04:38<2:48:28, 55.54s/it, training_loss=0.220]
# Epoch 3:   3%|▎         | 6/187 [05:33<2:47:21, 55.48s/it, training_loss=0.226]
# Epoch 3:   4%|▎         | 7/187 [06:28<2:46:26, 55.48s/it, training_loss=0.132]
# Epoch 3:   4%|▍         | 8/187 [07:24<2:45:20, 55.42s/it, training_loss=0.143]
# Epoch 3:   5%|▍         | 9/187 [08:19<2:44:14, 55.36s/it, training_loss=0.375]
# Epoch 3:   5%|▌         | 10/187 [09:14<2:43:17, 55.35s/it, training_loss=0.262]
# Epoch 3:   6%|▌         | 11/187 [10:10<2:42:45, 55.48s/it, training_loss=0.304]
# Epoch 3:   6%|▋         | 12/187 [11:05<2:41:32, 55.39s/it, training_loss=0.204]
# Epoch 3:   7%|▋         | 13/187 [12:01<2:40:35, 55.38s/it, training_loss=0.176]
# Epoch 3:   7%|▋         | 14/187 [12:56<2:39:32, 55.33s/it, training_loss=0.239]
# Epoch 3:   8%|▊         | 15/187 [13:51<2:38:42, 55.36s/it, training_loss=0.202]
# Epoch 3:   9%|▊         | 16/187 [14:46<2:37:39, 55.32s/it, training_loss=0.117]
# Epoch 3:   9%|▉         | 17/187 [15:42<2:36:40, 55.30s/it, training_loss=0.223]
# Epoch 3:  10%|▉         | 18/187 [16:37<2:35:45, 55.30s/it, training_loss=0.200]
# Epoch 3:  10%|█         | 19/187 [17:32<2:34:50, 55.30s/it, training_loss=0.205]
# Epoch 3:  11%|█         | 20/187 [18:28<2:33:53, 55.29s/it, training_loss=0.151]
# Epoch 3:  11%|█         | 21/187 [19:23<2:33:01, 55.31s/it, training_loss=0.236]
# Epoch 3:  12%|█▏        | 22/187 [20:18<2:32:04, 55.30s/it, training_loss=0.126]
# Epoch 3:  12%|█▏        | 23/187 [21:14<2:31:16, 55.34s/it, training_loss=0.140]
# Epoch 3:  13%|█▎        | 24/187 [22:09<2:30:16, 55.32s/it, training_loss=0.170]
# Epoch 3:  13%|█▎        | 25/187 [23:04<2:29:19, 55.31s/it, training_loss=0.211]
# Epoch 3:  14%|█▍        | 26/187 [24:00<2:28:24, 55.31s/it, training_loss=0.108]
# Epoch 3:  14%|█▍        | 27/187 [24:55<2:27:35, 55.35s/it, training_loss=0.281]
# Epoch 3:  15%|█▍        | 28/187 [25:51<2:27:09, 55.53s/it, training_loss=0.248]
# Epoch 3:  16%|█▌        | 29/187 [26:47<2:26:49, 55.75s/it, training_loss=0.236]
# Epoch 3:  16%|█▌        | 30/187 [27:43<2:25:45, 55.70s/it, training_loss=0.215]
# Epoch 3:  17%|█▋        | 31/187 [28:38<2:24:34, 55.61s/it, training_loss=0.209]
# Epoch 3:  17%|█▋        | 32/187 [29:33<2:23:20, 55.49s/it, training_loss=0.258]
# Epoch 3:  18%|█▊        | 33/187 [30:29<2:22:11, 55.40s/it, training_loss=0.200]
# Epoch 3:  18%|█▊        | 34/187 [31:24<2:21:12, 55.37s/it, training_loss=0.181]
# Epoch 3:  19%|█▊        | 35/187 [32:19<2:20:16, 55.37s/it, training_loss=0.148]
# Epoch 3:  19%|█▉        | 36/187 [33:15<2:19:15, 55.34s/it, training_loss=0.211]
# Epoch 3:  20%|█▉        | 37/187 [34:10<2:18:23, 55.36s/it, training_loss=0.185]
# Epoch 3:  20%|██        | 38/187 [35:05<2:17:19, 55.30s/it, training_loss=0.228]
# Epoch 3:  21%|██        | 39/187 [36:00<2:16:26, 55.31s/it, training_loss=0.135]
# Epoch 3:  21%|██▏       | 40/187 [36:56<2:15:26, 55.28s/it, training_loss=0.231]
# Epoch 3:  22%|██▏       | 41/187 [37:51<2:14:35, 55.31s/it, training_loss=0.194]
# Epoch 3:  22%|██▏       | 42/187 [38:46<2:13:46, 55.36s/it, training_loss=0.348]
# Epoch 3:  23%|██▎       | 43/187 [39:42<2:12:48, 55.33s/it, training_loss=0.139]
# Epoch 3:  24%|██▎       | 44/187 [40:37<2:11:55, 55.35s/it, training_loss=0.179]
# Epoch 3:  24%|██▍       | 45/187 [41:33<2:11:08, 55.41s/it, training_loss=0.186]
# Epoch 3:  25%|██▍       | 46/187 [42:28<2:10:06, 55.37s/it, training_loss=0.172]
# Epoch 3:  25%|██▌       | 47/187 [43:23<2:09:16, 55.40s/it, training_loss=0.174]
# Epoch 3:  26%|██▌       | 48/187 [44:19<2:08:18, 55.38s/it, training_loss=0.143]
# Epoch 3:  26%|██▌       | 49/187 [45:14<2:07:27, 55.42s/it, training_loss=0.177]
# Epoch 3:  27%|██▋       | 50/187 [46:10<2:06:38, 55.46s/it, training_loss=0.182]
# Epoch 3:  27%|██▋       | 51/187 [47:05<2:05:35, 55.41s/it, training_loss=0.228]
# Epoch 3:  28%|██▊       | 52/187 [48:00<2:04:37, 55.39s/it, training_loss=0.220]
# Epoch 3:  28%|██▊       | 53/187 [48:56<2:03:42, 55.40s/it, training_loss=0.122]
# Epoch 3:  29%|██▉       | 54/187 [49:51<2:02:49, 55.41s/it, training_loss=0.155]
# Epoch 3:  29%|██▉       | 55/187 [50:48<2:02:48, 55.82s/it, training_loss=0.199]
# Epoch 3:  30%|██▉       | 56/187 [51:44<2:01:46, 55.77s/it, training_loss=0.136]
# Epoch 3:  30%|███       | 57/187 [52:39<2:00:36, 55.67s/it, training_loss=0.107]
# Epoch 3:  31%|███       | 58/187 [53:35<1:59:31, 55.59s/it, training_loss=0.154]
# Epoch 3:  32%|███▏      | 59/187 [54:30<1:58:23, 55.49s/it, training_loss=0.250]
# Epoch 3:  32%|███▏      | 60/187 [55:25<1:57:19, 55.43s/it, training_loss=0.246]
# Epoch 3:  33%|███▎      | 61/187 [56:21<1:56:27, 55.46s/it, training_loss=0.108]
# Epoch 3:  33%|███▎      | 62/187 [57:16<1:55:24, 55.40s/it, training_loss=0.216]
# Epoch 3:  34%|███▎      | 63/187 [58:11<1:54:24, 55.36s/it, training_loss=0.161]
# Epoch 3:  34%|███▍      | 64/187 [59:07<1:53:28, 55.35s/it, training_loss=0.183]
# Epoch 3:  35%|███▍      | 65/187 [1:00:02<1:52:30, 55.33s/it, training_loss=0.141]
# Epoch 3:  35%|███▌      | 66/187 [1:00:57<1:51:35, 55.34s/it, training_loss=0.237]
# Epoch 3:  36%|███▌      | 67/187 [1:01:52<1:50:33, 55.28s/it, training_loss=0.081]
# Epoch 3:  36%|███▋      | 68/187 [1:02:47<1:49:33, 55.24s/it, training_loss=0.175]
# Epoch 3:  37%|███▋      | 69/187 [1:03:43<1:48:42, 55.28s/it, training_loss=0.102]
# Epoch 3:  37%|███▋      | 70/187 [1:04:38<1:47:55, 55.35s/it, training_loss=0.152]
# Epoch 3:  38%|███▊      | 71/187 [1:05:34<1:46:59, 55.34s/it, training_loss=0.181]
# Epoch 3:  39%|███▊      | 72/187 [1:06:29<1:45:59, 55.30s/it, training_loss=0.164]
# Epoch 3:  39%|███▉      | 73/187 [1:07:24<1:45:02, 55.28s/it, training_loss=0.138]
# Epoch 3:  40%|███▉      | 74/187 [1:08:19<1:44:05, 55.27s/it, training_loss=0.112]
# Epoch 3:  40%|████      | 75/187 [1:09:15<1:43:11, 55.28s/it, training_loss=0.147]
# Epoch 3:  41%|████      | 76/187 [1:10:10<1:42:16, 55.28s/it, training_loss=0.159]
# Epoch 3:  41%|████      | 77/187 [1:11:05<1:41:23, 55.31s/it, training_loss=0.225]
# Epoch 3:  42%|████▏     | 78/187 [1:12:01<1:40:28, 55.31s/it, training_loss=0.243]
# Epoch 3:  42%|████▏     | 79/187 [1:12:56<1:39:27, 55.26s/it, training_loss=0.180]
# Epoch 3:  43%|████▎     | 80/187 [1:13:51<1:38:31, 55.25s/it, training_loss=0.194]
# Epoch 3:  43%|████▎     | 81/187 [1:14:46<1:37:38, 55.27s/it, training_loss=0.134]
# Epoch 3:  44%|████▍     | 82/187 [1:15:42<1:36:42, 55.26s/it, training_loss=0.152]
# Epoch 3:  44%|████▍     | 83/187 [1:16:37<1:35:46, 55.26s/it, training_loss=0.083]
# Epoch 3:  45%|████▍     | 84/187 [1:17:32<1:34:50, 55.25s/it, training_loss=0.171]
# Epoch 3:  45%|████▌     | 85/187 [1:18:27<1:33:57, 55.27s/it, training_loss=0.192]
# Epoch 3:  46%|████▌     | 86/187 [1:19:22<1:32:55, 55.20s/it, training_loss=0.194]
# Epoch 3:  47%|████▋     | 87/187 [1:20:18<1:32:02, 55.22s/it, training_loss=0.118]
# Epoch 3:  47%|████▋     | 88/187 [1:21:13<1:31:07, 55.22s/it, training_loss=0.175]
# Epoch 3:  48%|████▊     | 89/187 [1:22:08<1:30:18, 55.29s/it, training_loss=0.153]
# Epoch 3:  48%|████▊     | 90/187 [1:23:04<1:29:20, 55.26s/it, training_loss=0.158]
# Epoch 3:  49%|████▊     | 91/187 [1:23:59<1:28:27, 55.28s/it, training_loss=0.123]
# Epoch 3:  49%|████▉     | 92/187 [1:24:54<1:27:31, 55.28s/it, training_loss=0.138]
# Epoch 3:  50%|████▉     | 93/187 [1:25:49<1:26:34, 55.27s/it, training_loss=0.186]
# Epoch 3:  50%|█████     | 94/187 [1:26:45<1:25:36, 55.23s/it, training_loss=0.111]
# Epoch 3:  51%|█████     | 95/187 [1:27:40<1:24:38, 55.20s/it, training_loss=0.188]
# Epoch 3:  51%|█████▏    | 96/187 [1:28:35<1:23:44, 55.22s/it, training_loss=0.135]
# Epoch 3:  52%|█████▏    | 97/187 [1:29:30<1:22:50, 55.23s/it, training_loss=0.176]
# Epoch 3:  52%|█████▏    | 98/187 [1:30:25<1:21:56, 55.24s/it, training_loss=0.144]
# Epoch 3:  53%|█████▎    | 99/187 [1:31:21<1:20:58, 55.21s/it, training_loss=0.120]
# Epoch 3:  53%|█████▎    | 100/187 [1:32:16<1:20:09, 55.29s/it, training_loss=0.169]
# Epoch 3:  54%|█████▍    | 101/187 [1:33:11<1:19:15, 55.30s/it, training_loss=0.091]
# Epoch 3:  55%|█████▍    | 102/187 [1:34:07<1:18:20, 55.29s/it, training_loss=0.258]
# Epoch 3:  55%|█████▌    | 103/187 [1:35:02<1:17:25, 55.30s/it, training_loss=0.138]
# Epoch 3:  56%|█████▌    | 104/187 [1:35:57<1:16:27, 55.27s/it, training_loss=0.267]
# Epoch 3:  56%|█████▌    | 105/187 [1:36:52<1:15:32, 55.28s/it, training_loss=0.147]
# Epoch 3:  57%|█████▋    | 106/187 [1:37:48<1:14:36, 55.27s/it, training_loss=0.193]
# Epoch 3:  57%|█████▋    | 107/187 [1:38:43<1:13:41, 55.27s/it, training_loss=0.048]
# Epoch 3:  58%|█████▊    | 108/187 [1:39:38<1:12:44, 55.25s/it, training_loss=0.091]
# Epoch 3:  58%|█████▊    | 109/187 [1:40:33<1:11:49, 55.25s/it, training_loss=0.110]
# Epoch 3:  59%|█████▉    | 110/187 [1:41:29<1:10:54, 55.26s/it, training_loss=0.184]
# Epoch 3:  59%|█████▉    | 111/187 [1:42:25<1:10:13, 55.44s/it, training_loss=0.120]
# Epoch 3:  60%|█████▉    | 112/187 [1:43:20<1:09:17, 55.43s/it, training_loss=0.145]
# Epoch 3:  60%|██████    | 113/187 [1:44:15<1:08:18, 55.38s/it, training_loss=0.067]
# Epoch 3:  61%|██████    | 114/187 [1:45:11<1:07:21, 55.36s/it, training_loss=0.143]
# Epoch 3:  61%|██████▏   | 115/187 [1:46:06<1:06:22, 55.31s/it, training_loss=0.070]
# Epoch 3:  62%|██████▏   | 116/187 [1:47:01<1:05:28, 55.33s/it, training_loss=0.160]
# Epoch 3:  63%|██████▎   | 117/187 [1:47:56<1:04:31, 55.31s/it, training_loss=0.178]
# Epoch 3:  63%|██████▎   | 118/187 [1:48:52<1:03:39, 55.36s/it, training_loss=0.184]
# Epoch 3:  64%|██████▎   | 119/187 [1:49:47<1:02:38, 55.26s/it, training_loss=0.181]
# Epoch 3:  64%|██████▍   | 120/187 [1:50:42<1:01:46, 55.32s/it, training_loss=0.175]
# Epoch 3:  65%|██████▍   | 121/187 [1:51:38<1:00:55, 55.38s/it, training_loss=0.067]
# Epoch 3:  65%|██████▌   | 122/187 [1:52:33<1:00:00, 55.39s/it, training_loss=0.111]
# Epoch 3:  66%|██████▌   | 123/187 [1:53:29<59:03, 55.36s/it, training_loss=0.061]
# Epoch 3:  66%|██████▋   | 124/187 [1:54:24<58:06, 55.35s/it, training_loss=0.202]
# Epoch 3:  67%|██████▋   | 125/187 [1:55:19<57:10, 55.33s/it, training_loss=0.164]
# Epoch 3:  67%|██████▋   | 126/187 [1:56:15<56:15, 55.34s/it, training_loss=0.084]
# Epoch 3:  68%|██████▊   | 127/187 [1:57:10<55:18, 55.31s/it, training_loss=0.197]
# Epoch 3:  68%|██████▊   | 128/187 [1:58:05<54:20, 55.27s/it, training_loss=0.220]
# Epoch 3:  69%|██████▉   | 129/187 [1:59:00<53:24, 55.26s/it, training_loss=0.094]
# Epoch 3:  70%|██████▉   | 130/187 [1:59:56<52:32, 55.30s/it, training_loss=0.198]
# Epoch 3:  70%|███████   | 131/187 [2:00:51<51:36, 55.29s/it, training_loss=0.189]
# Epoch 3:  71%|███████   | 132/187 [2:01:46<50:38, 55.24s/it, training_loss=0.161]
# Epoch 3:  71%|███████   | 133/187 [2:02:41<49:44, 55.27s/it, training_loss=0.115]
# Epoch 3:  72%|███████▏  | 134/187 [2:03:37<48:51, 55.31s/it, training_loss=0.208]
# Epoch 3:  72%|███████▏  | 135/187 [2:04:32<47:59, 55.38s/it, training_loss=0.063]
# Epoch 3:  73%|███████▎  | 136/187 [2:05:28<47:04, 55.39s/it, training_loss=0.107]
# Epoch 3:  73%|███████▎  | 137/187 [2:06:23<46:07, 55.34s/it, training_loss=0.169]
# Epoch 3:  74%|███████▍  | 138/187 [2:07:18<45:10, 55.32s/it, training_loss=0.117]
# Epoch 3:  74%|███████▍  | 139/187 [2:08:13<44:15, 55.32s/it, training_loss=0.116]
# Epoch 3:  75%|███████▍  | 140/187 [2:09:09<43:19, 55.31s/it, training_loss=0.136]
# Epoch 3:  75%|███████▌  | 141/187 [2:10:04<42:22, 55.27s/it, training_loss=0.228]
# Epoch 3:  76%|███████▌  | 142/187 [2:10:59<41:27, 55.28s/it, training_loss=0.060]
# Epoch 3:  76%|███████▋  | 143/187 [2:11:54<40:30, 55.23s/it, training_loss=0.061]
# Epoch 3:  77%|███████▋  | 144/187 [2:12:50<39:35, 55.24s/it, training_loss=0.186]
# Epoch 3:  78%|███████▊  | 145/187 [2:13:45<38:38, 55.21s/it, training_loss=0.158]
# Epoch 3:  78%|███████▊  | 146/187 [2:14:40<37:45, 55.25s/it, training_loss=0.257]
# Epoch 3:  79%|███████▊  | 147/187 [2:15:35<36:48, 55.20s/it, training_loss=0.156]
# Epoch 3:  79%|███████▉  | 148/187 [2:16:30<35:53, 55.22s/it, training_loss=0.137]
# Epoch 3:  80%|███████▉  | 149/187 [2:17:26<34:57, 55.21s/it, training_loss=0.154]
# Epoch 3:  80%|████████  | 150/187 [2:18:21<34:04, 55.25s/it, training_loss=0.106]
# Epoch 3:  81%|████████  | 151/187 [2:19:16<33:08, 55.24s/it, training_loss=0.085]
# Epoch 3:  81%|████████▏ | 152/187 [2:20:11<32:12, 55.22s/it, training_loss=0.183]
# Epoch 3:  82%|████████▏ | 153/187 [2:21:07<31:19, 55.27s/it, training_loss=0.108]
# Epoch 3:  82%|████████▏ | 154/187 [2:22:02<30:24, 55.29s/it, training_loss=0.186]
# Epoch 3:  83%|████████▎ | 155/187 [2:22:57<29:27, 55.22s/it, training_loss=0.154]
# Epoch 3:  83%|████████▎ | 156/187 [2:23:52<28:31, 55.22s/it, training_loss=0.099]
# Epoch 3:  84%|████████▍ | 157/187 [2:24:48<27:36, 55.21s/it, training_loss=0.114]
# Epoch 3:  84%|████████▍ | 158/187 [2:25:43<26:41, 55.24s/it, training_loss=0.145]
# Epoch 3:  85%|████████▌ | 159/187 [2:26:38<25:47, 55.25s/it, training_loss=0.155]
# Epoch 3:  86%|████████▌ | 160/187 [2:27:33<24:52, 55.27s/it, training_loss=0.144]
# Epoch 3:  86%|████████▌ | 161/187 [2:28:29<23:57, 55.28s/it, training_loss=0.127]
# Epoch 3:  87%|████████▋ | 162/187 [2:29:24<23:02, 55.28s/it, training_loss=0.088]
# Epoch 3:  87%|████████▋ | 163/187 [2:30:19<22:06, 55.27s/it, training_loss=0.193]
# Epoch 3:  88%|████████▊ | 164/187 [2:31:15<21:10, 55.26s/it, training_loss=0.174]
# Epoch 3:  88%|████████▊ | 165/187 [2:32:10<20:15, 55.24s/it, training_loss=0.124]
# Epoch 3:  89%|████████▉ | 166/187 [2:33:05<19:20, 55.25s/it, training_loss=0.082]
# Epoch 3:  89%|████████▉ | 167/187 [2:34:00<18:25, 55.26s/it, training_loss=0.064]
# Epoch 3:  90%|████████▉ | 168/187 [2:34:55<17:29, 55.24s/it, training_loss=0.126]
# Epoch 3:  90%|█████████ | 169/187 [2:35:51<16:34, 55.24s/it, training_loss=0.125]
# Epoch 3:  91%|█████████ | 170/187 [2:36:46<15:39, 55.26s/it, training_loss=0.137]
# Epoch 3:  91%|█████████▏| 171/187 [2:37:41<14:43, 55.24s/it, training_loss=0.169]
# Epoch 3:  92%|█████████▏| 172/187 [2:38:36<13:48, 55.23s/it, training_loss=0.129]
# Epoch 3:  93%|█████████▎| 173/187 [2:39:32<12:53, 55.23s/it, training_loss=0.190]
# Epoch 3:  93%|█████████▎| 174/187 [2:40:27<11:58, 55.25s/it, training_loss=0.161]
# Epoch 3:  94%|█████████▎| 175/187 [2:41:22<11:02, 55.22s/it, training_loss=0.129]
# Epoch 3:  94%|█████████▍| 176/187 [2:42:17<10:07, 55.20s/it, training_loss=0.105]
# Epoch 3:  95%|█████████▍| 177/187 [2:43:12<09:12, 55.20s/it, training_loss=0.119]
# Epoch 3:  95%|█████████▌| 178/187 [2:44:08<08:17, 55.25s/it, training_loss=0.133]
# Epoch 3:  96%|█████████▌| 179/187 [2:45:03<07:22, 55.28s/it, training_loss=0.205]
# Epoch 3:  96%|█████████▋| 180/187 [2:45:59<06:27, 55.33s/it, training_loss=0.127]
# Epoch 3:  97%|█████████▋| 181/187 [2:46:54<05:31, 55.28s/it, training_loss=0.249]
# Epoch 3:  97%|█████████▋| 182/187 [2:47:49<04:36, 55.26s/it, training_loss=0.067]
# Epoch 3:  98%|█████████▊| 183/187 [2:48:44<03:40, 55.24s/it, training_loss=0.196]
# Epoch 3:  98%|█████████▊| 184/187 [2:49:39<02:45, 55.20s/it, training_loss=0.175]
# Epoch 3:  99%|█████████▉| 185/187 [2:50:35<01:50, 55.22s/it, training_loss=0.083]
# Epoch 3:  99%|█████████▉| 186/187 [2:51:30<00:55, 55.24s/it, training_loss=0.193]
# Epoch 3: 100%|██████████| 187/187 [2:51:49<00:00, 44.31s/it, training_loss=0.126]
#  40%|████      | 2/5 [9:31:39<9:53:16, 11865.53s/it]
# Epoch 3
# Training loss: 0.4899129242023682
#  60%|██████    | 3/5 [9:45:09<6:24:09, 11524.96s/it]
# Validation loss: 0.42634263809056994
# F1 Score (Weighted): 0.8876997228325014
# ------
# Epoch 4:   0%|          | 0/187 [00:00<?, ?it/s]
# Epoch 4:   1%|          | 1/187 [00:56<2:53:54, 56.10s/it, training_loss=0.100]
# Epoch 4:   1%|          | 2/187 [01:51<2:51:47, 55.72s/it, training_loss=0.109]
# Epoch 4:   2%|▏         | 3/187 [02:47<2:50:38, 55.64s/it, training_loss=0.144]
# Epoch 4:   2%|▏         | 4/187 [03:42<2:49:10, 55.47s/it, training_loss=0.246]
# Epoch 4:   3%|▎         | 5/187 [04:37<2:48:00, 55.39s/it, training_loss=0.080]
# Epoch 4:   3%|▎         | 6/187 [05:32<2:47:06, 55.39s/it, training_loss=0.221]
# Epoch 4:   4%|▎         | 7/187 [06:28<2:46:06, 55.37s/it, training_loss=0.146]
# Epoch 4:   4%|▍         | 8/187 [07:23<2:45:02, 55.32s/it, training_loss=0.090]
# Epoch 4:   5%|▍         | 9/187 [08:18<2:44:08, 55.33s/it, training_loss=0.216]
# Epoch 4:   5%|▌         | 10/187 [09:14<2:43:20, 55.37s/it, training_loss=0.170]
# Epoch 4:   6%|▌         | 11/187 [10:09<2:42:30, 55.40s/it, training_loss=0.086]
# Epoch 4:   6%|▋         | 12/187 [11:04<2:41:22, 55.33s/it, training_loss=0.145]
# ...
# Validation loss: 0.34002479982185874
# F1 Score (Weighted): 0.9174618364116568
# ------
# Epoch 5:   0%|          | 0/187 [00:00<?, ?it/s]
# Epoch 5:   1%|          | 1/187 [00:56<2:53:35, 56.00s/it, training_loss=0.137]
# Epoch 5:   1%|          | 2/187 [01:51<2:51:52, 55.74s/it, training_loss=0.118]
# Epoch 5:   2%|▏         | 3/187 [02:47<2:50:40, 55.65s/it, training_loss=0.064]
# Epoch 5:   2%|▏         | 4/187 [03:42<2:49:25, 55.55s/it, training_loss=0.076]
# Epoch 5:   3%|▎         | 5/187 [04:37<2:48:10, 55.44s/it, training_loss=0.132]
# Epoch 5:   3%|▎         | 6/187 [05:33<2:47:34, 55.55s/it, training_loss=0.134]
# Epoch 5:   4%|▎         | 7/187 [22:06<18:05:50, 361.95s/it, training_loss=0.149]
# Epoch 5:   4%|▍         | 8/187 [38:33<27:53:26, 560.93s/it, training_loss=0.090]
# Epoch 5:   5%|▍         | 9/187 [56:15<35:28:54, 717.61s/it, training_loss=0.153]
# Epoch 5:   5%|▌         | 10/187 [1:02:42<30:16:03, 615.61s/it, training_loss=0.062]
# Epoch 5:   6%|▌         | 11/187 [1:03:37<21:42:31, 444.04s/it, training_loss=0.076]
# Epoch 5:   6%|▋         | 12/187 [1:04:32<15:49:36, 325.58s/it, training_loss=0.068]
# Epoch 5:   7%|▋         | 13/187 [1:05:27<11:46:30, 243.62s/it, training_loss=0.109]
# Epoch 5:   7%|▋         | 14/187 [1:06:22<8:58:10, 186.65s/it, training_loss=0.076]
# Epoch 5:   8%|▊         | 15/187 [1:07:17<7:01:27, 147.02s/it, training_loss=0.138]
# Epoch 5:   9%|▊         | 16/187 [1:08:12<5:40:26, 119.45s/it, training_loss=0.037]
# Epoch 5:   9%|▉         | 17/187 [1:09:08<4:43:48, 100.17s/it, training_loss=0.105]
# Epoch 5:  10%|▉         | 18/187 [1:10:03<4:04:04, 86.65s/it, training_loss=0.072]
# Epoch 5:  10%|█         | 19/187 [1:10:58<3:36:10, 77.21s/it, training_loss=0.132]
# Epoch 5:  11%|█         | 20/187 [1:11:54<3:16:40, 70.66s/it, training_loss=0.089]
# Epoch 5:  11%|█         | 21/187 [1:12:49<3:02:38, 66.01s/it, training_loss=0.158]
# Epoch 5:  12%|█▏        | 22/187 [1:13:46<2:54:16, 63.37s/it, training_loss=0.052]
# Epoch 5:  12%|█▏        | 23/187 [1:14:41<2:46:49, 61.03s/it, training_loss=0.069]
# Epoch 5:  13%|█▎        | 24/187 [1:15:37<2:41:01, 59.27s/it, training_loss=0.064]
# Epoch 5:  13%|█▎        | 25/187 [1:16:32<2:36:54, 58.12s/it, training_loss=0.125]
# Epoch 5:  14%|█▍        | 26/187 [1:17:28<2:33:59, 57.39s/it, training_loss=0.077]
# Epoch 5:  14%|█▍        | 27/187 [1:18:25<2:33:04, 57.40s/it, training_loss=0.120]
# Epoch 5:  15%|█▍        | 28/187 [1:19:21<2:30:44, 56.88s/it, training_loss=0.191]
# Epoch 5:  16%|█▌        | 29/187 [1:20:16<2:28:44, 56.49s/it, training_loss=0.122]
# Epoch 5:  16%|█▌        | 30/187 [1:21:12<2:27:10, 56.25s/it, training_loss=0.094]
# Epoch 5:  17%|█▋        | 31/187 [1:22:09<2:26:59, 56.54s/it, training_loss=0.095]
# Epoch 5:  17%|█▋        | 32/187 [1:23:05<2:25:29, 56.32s/it, training_loss=0.031]
# Epoch 5:  18%|█▊        | 33/187 [1:24:01<2:23:58, 56.09s/it, training_loss=0.070]
# Epoch 5:  18%|█▊        | 34/187 [1:24:56<2:22:37, 55.93s/it, training_loss=0.050]
# Epoch 5:  19%|█▊        | 35/187 [1:25:52<2:21:39, 55.92s/it, training_loss=0.143]
# Epoch 5:  19%|█▉        | 36/187 [1:26:49<2:21:07, 56.08s/it, training_loss=0.046]
# Epoch 5:  20%|█▉        | 37/187 [1:27:44<2:19:42, 55.88s/it, training_loss=0.052]
# Epoch 5:  20%|██        | 38/187 [1:28:40<2:18:44, 55.87s/it, training_loss=0.043]
# Epoch 5:  21%|██        | 39/187 [1:29:35<2:17:33, 55.77s/it, training_loss=0.022]
# Epoch 5:  21%|██▏       | 40/187 [1:30:31<2:16:27, 55.70s/it, training_loss=0.080]
# Epoch 5:  22%|██▏       | 41/187 [1:31:26<2:15:24, 55.65s/it, training_loss=0.073]
# Epoch 5:  22%|██▏       | 42/187 [1:32:22<2:14:25, 55.62s/it, training_loss=0.083]
# Epoch 5:  23%|██▎       | 43/187 [1:33:17<2:13:15, 55.52s/it, training_loss=0.049]
# Epoch 5:  24%|██▎       | 44/187 [1:34:13<2:12:19, 55.52s/it, training_loss=0.070]
# Epoch 5:  24%|██▍       | 45/187 [1:35:08<2:11:14, 55.46s/it, training_loss=0.075]
# Epoch 5:  25%|██▍       | 46/187 [1:36:04<2:10:24, 55.49s/it, training_loss=0.089]
# Epoch 5:  25%|██▌       | 47/187 [1:36:59<2:09:25, 55.47s/it, training_loss=0.094]
# Epoch 5:  26%|██▌       | 48/187 [1:37:54<2:08:20, 55.40s/it, training_loss=0.073]
# Epoch 5:  26%|██▌       | 49/187 [1:38:50<2:07:24, 55.40s/it, training_loss=0.080]
# Epoch 5:  27%|██▋       | 50/187 [1:39:45<2:06:21, 55.34s/it, training_loss=0.101]
# Epoch 5:  27%|██▋       | 51/187 [1:40:40<2:05:30, 55.37s/it, training_loss=0.150]
# Epoch 5:  28%|██▊       | 52/187 [1:46:29<5:22:40, 143.41s/it, training_loss=0.089]
# Epoch 5:  28%|██▊       | 53/187 [1:47:25<4:21:23, 117.04s/it, training_loss=0.073]
# Epoch 5:  29%|██▉       | 54/187 [1:48:20<3:38:30, 98.58s/it, training_loss=0.044]
# Epoch 5:  29%|██▉       | 55/187 [1:49:16<3:08:21, 85.62s/it, training_loss=0.076]
# Epoch 5:  30%|██▉       | 56/187 [1:50:11<2:47:09, 76.56s/it, training_loss=0.158]
# Epoch 5:  30%|███       | 57/187 [1:51:07<2:32:14, 70.26s/it, training_loss=0.054]
# Epoch 5:  31%|███       | 58/187 [1:52:02<2:21:42, 65.91s/it, training_loss=0.159]
# Epoch 5:  32%|███▏      | 59/187 [1:52:58<2:13:59, 62.81s/it, training_loss=0.033]
# Epoch 5:  32%|███▏      | 60/187 [1:53:53<2:08:19, 60.63s/it, training_loss=0.112]
# Epoch 5:  33%|███▎      | 61/187 [1:54:49<2:03:58, 59.04s/it, training_loss=0.116]
# Epoch 5:  33%|███▎      | 62/187 [1:55:44<2:00:38, 57.91s/it, training_loss=0.147]
# Epoch 5:  34%|███▎      | 63/187 [1:56:40<1:58:20, 57.27s/it, training_loss=0.145]
# Epoch 5:  34%|███▍      | 64/187 [1:57:38<1:57:38, 57.39s/it, training_loss=0.076]
# Epoch 5:  35%|███▍      | 65/187 [2:13:47<11:13:01, 331.00s/it, training_loss=0.106]
# Epoch 5:  35%|███▌      | 66/187 [2:43:02<25:29:08, 758.25s/it, training_loss=0.137]
# Epoch 5:  36%|███▌      | 67/187 [2:45:10<18:58:09, 569.08s/it, training_loss=0.088]
# Epoch 5:  36%|███▋      | 68/187 [2:46:05<13:42:45, 414.84s/it, training_loss=0.108]
# Epoch 5:  37%|███▋      | 69/187 [2:47:00<10:03:25, 306.83s/it, training_loss=0.113]
# Epoch 5:  37%|███▋      | 70/187 [2:47:54<7:30:57, 231.26s/it, training_loss=0.069]
# Epoch 5:  38%|███▊      | 71/187 [2:48:50<5:44:58, 178.43s/it, training_loss=0.109]
# Epoch 5:  39%|███▊      | 72/187 [2:49:45<4:31:14, 141.52s/it, training_loss=0.050]
# Epoch 5:  39%|███▉      | 73/187 [2:50:41<3:39:56, 115.76s/it, training_loss=0.199]
# Epoch 5:  40%|███▉      | 74/187 [2:51:36<3:03:51, 97.62s/it, training_loss=0.146]
# Epoch 5:  40%|████      | 75/187 [2:52:31<2:38:32, 84.93s/it, training_loss=0.083]
# Epoch 5:  41%|████      | 76/187 [2:53:27<2:20:47, 76.11s/it, training_loss=0.101]
# Epoch 5:  41%|████      | 77/187 [2:54:23<2:08:41, 70.20s/it, training_loss=0.110]
# Epoch 5:  42%|████▏     | 78/187 [2:55:20<1:59:59, 66.05s/it, training_loss=0.121]
# Epoch 5:  42%|████▏     | 79/187 [2:56:17<1:54:06, 63.39s/it, training_loss=0.100]
# Epoch 5:  43%|████▎     | 80/187 [2:57:13<1:49:18, 61.29s/it, training_loss=0.043]
# Epoch 5:  43%|████▎     | 81/187 [2:58:10<1:45:45, 59.87s/it, training_loss=0.106]
# Epoch 5:  44%|████▍     | 82/187 [2:59:07<1:43:14, 59.00s/it, training_loss=0.089]
# Epoch 5:  44%|████▍     | 83/187 [3:00:03<1:41:05, 58.32s/it, training_loss=0.089]
# Epoch 5:  45%|████▍     | 84/187 [3:00:59<1:38:44, 57.52s/it, training_loss=0.053]
# Epoch 5:  45%|████▌     | 85/187 [3:01:56<1:37:35, 57.41s/it, training_loss=0.066]
# Epoch 5:  46%|████▌     | 86/187 [3:02:52<1:35:43, 56.86s/it, training_loss=0.059]
# Epoch 5:  47%|████▋     | 87/187 [3:03:47<1:34:04, 56.45s/it, training_loss=0.075]
# Epoch 5:  47%|████▋     | 88/187 [3:04:43<1:32:35, 56.12s/it, training_loss=0.074]
# Epoch 5:  48%|████▊     | 89/187 [3:05:38<1:31:28, 56.01s/it, training_loss=0.027]
# Epoch 5:  48%|████▊     | 90/187 [3:06:34<1:30:17, 55.85s/it, training_loss=0.139]
# Epoch 5:  49%|████▊     | 91/187 [3:07:29<1:29:08, 55.71s/it, training_loss=0.100]
# Epoch 5:  49%|████▉     | 92/187 [3:08:25<1:28:06, 55.65s/it, training_loss=0.172]
# Epoch 5:  50%|████▉     | 93/187 [3:09:20<1:27:03, 55.57s/it, training_loss=0.037]
# Epoch 5:  50%|█████     | 94/187 [3:10:16<1:26:27, 55.78s/it, training_loss=0.095]
# Epoch 5:  51%|█████     | 95/187 [3:11:12<1:25:34, 55.81s/it, training_loss=0.035]
# Epoch 5:  51%|█████▏    | 96/187 [3:12:08<1:24:32, 55.74s/it, training_loss=0.047]
# Epoch 5:  52%|█████▏    | 97/187 [3:13:04<1:23:34, 55.72s/it, training_loss=0.109]
# Epoch 5:  52%|█████▏    | 98/187 [3:14:01<1:23:14, 56.12s/it, training_loss=0.114]
# Epoch 5:  53%|█████▎    | 99/187 [3:14:57<1:22:19, 56.13s/it, training_loss=0.137]
# Epoch 5:  53%|█████▎    | 100/187 [3:15:52<1:21:11, 55.99s/it, training_loss=0.114]
# Epoch 5:  54%|█████▍    | 101/187 [3:16:48<1:20:00, 55.82s/it, training_loss=0.094]
# Epoch 5:  55%|█████▍    | 102/187 [3:17:43<1:18:57, 55.74s/it, training_loss=0.096]
# Epoch 5:  55%|█████▌    | 103/187 [3:18:39<1:17:57, 55.68s/it, training_loss=0.101]
# Epoch 5:  56%|█████▌    | 104/187 [3:19:34<1:16:53, 55.59s/it, training_loss=0.134]
# Epoch 5:  56%|█████▌    | 105/187 [3:20:30<1:15:51, 55.51s/it, training_loss=0.063]
# Epoch 5:  57%|█████▋    | 106/187 [3:21:25<1:14:51, 55.45s/it, training_loss=0.203]
# Epoch 5:  57%|█████▋    | 107/187 [3:22:21<1:14:05, 55.56s/it, training_loss=0.078]
# Epoch 5:  58%|█████▊    | 108/187 [3:23:17<1:13:32, 55.85s/it, training_loss=0.075]
# Epoch 5:  58%|█████▊    | 109/187 [3:24:13<1:12:35, 55.83s/it, training_loss=0.092]
# Epoch 5:  59%|█████▉    | 110/187 [3:25:09<1:11:39, 55.83s/it, training_loss=0.133]
# Epoch 5:  59%|█████▉    | 111/187 [3:26:05<1:10:37, 55.76s/it, training_loss=0.095]
# Epoch 5:  60%|█████▉    | 112/187 [3:27:00<1:09:35, 55.67s/it, training_loss=0.079]
# Epoch 5:  60%|██████    | 113/187 [3:42:00<6:21:01, 308.94s/it, training_loss=0.048]
# Epoch 5:  61%|██████    | 114/187 [3:42:55<4:43:18, 232.86s/it, training_loss=0.107]
# Epoch 5:  76%|███████▋  | 143/187 [6:34:58<1:12:47, 99.26s/it, training_loss=0.061]
# Epoch 5:  77%|███████▋  | 144/187 [6:35:53<1:01:41, 86.08s/it, training_loss=0.107]
# Epoch 5:  78%|███████▊  | 145/187 [6:36:49<53:48, 76.86s/it, training_loss=0.113]
# Epoch 5:  78%|███████▊  | 146/187 [6:37:44<48:08, 70.45s/it, training_loss=0.104]
# Epoch 5:  79%|███████▊  | 147/187 [6:38:40<44:00, 66.02s/it, training_loss=0.130]
# Epoch 5:  79%|███████▉  | 148/187 [6:39:35<40:51, 62.86s/it, training_loss=0.057]
# Epoch 5:  80%|███████▉  | 149/187 [6:40:31<38:22, 60.60s/it, training_loss=0.041]
# Epoch 5:  80%|████████  | 150/187 [6:41:26<36:26, 59.08s/it, training_loss=0.045]
# Epoch 5:  81%|████████  | 151/187 [6:59:38<3:41:19, 368.89s/it, training_loss=0.025]
# Epoch 5:  81%|████████▏ | 152/187 [7:17:46<5:41:00, 584.59s/it, training_loss=0.079]
# Epoch 5:  82%|████████▏ | 153/187 [7:29:59<5:56:27, 629.05s/it, training_loss=0.038]
# Epoch 5:  82%|████████▏ | 154/187 [7:30:54<4:11:16, 456.86s/it, training_loss=0.048]
# Epoch 5:  83%|████████▎ | 155/187 [7:33:43<3:17:42, 370.71s/it, training_loss=0.054]
# Epoch 5:  83%|████████▎ | 156/187 [7:34:39<2:22:39, 276.13s/it, training_loss=0.046]
# Epoch 5:  84%|████████▍ | 157/187 [7:35:34<1:44:58, 209.96s/it, training_loss=0.174]
# Epoch 5:  84%|████████▍ | 158/187 [7:36:30<1:19:05, 163.65s/it, training_loss=0.092]
# Epoch 5:  85%|████████▌ | 159/187 [7:37:26<1:01:14, 131.22s/it, training_loss=0.045]
# Epoch 5:  86%|████████▌ | 160/187 [7:38:22<48:53, 108.64s/it, training_loss=0.115]
# Epoch 5:  86%|████████▌ | 161/187 [7:39:17<40:11, 92.74s/it, training_loss=0.076]
# Epoch 5:  87%|████████▋ | 162/187 [7:40:13<33:59, 81.56s/it, training_loss=0.049]
# Epoch 5:  87%|████████▋ | 163/187 [7:41:08<29:30, 73.79s/it, training_loss=0.123]
# Epoch 5:  88%|████████▊ | 164/187 [7:42:04<26:10, 68.29s/it, training_loss=0.096]
# Epoch 5:  88%|████████▊ | 165/187 [7:42:59<23:37, 64.45s/it, training_loss=0.057]
# Epoch 5:  89%|████████▉ | 166/187 [7:43:55<21:36, 61.75s/it, training_loss=0.045]
# Epoch 5:  89%|████████▉ | 167/187 [7:44:50<19:58, 59.91s/it, training_loss=0.086]
# Epoch 5:  90%|████████▉ | 168/187 [7:45:46<18:33, 58.60s/it, training_loss=0.114]
# Epoch 5:  90%|█████████ | 169/187 [7:46:41<17:17, 57.63s/it, training_loss=0.050]
# Epoch 5:  91%|█████████ | 170/187 [7:47:37<16:09, 57.06s/it, training_loss=0.139]
# Epoch 5:  91%|█████████▏| 171/187 [7:48:33<15:05, 56.62s/it, training_loss=0.094]
# Epoch 5:  92%|█████████▏| 172/187 [7:49:28<14:04, 56.33s/it, training_loss=0.067]
# Epoch 5:  93%|█████████▎| 173/187 [7:50:26<13:13, 56.71s/it, training_loss=0.116]
# Epoch 5:  93%|█████████▎| 174/187 [7:51:22<12:14, 56.51s/it, training_loss=0.087]
# Epoch 5:  94%|█████████▎| 175/187 [7:52:17<11:14, 56.24s/it, training_loss=0.085]
# Epoch 5:  94%|█████████▍| 176/187 [7:53:13<10:17, 56.13s/it, training_loss=0.086]
# Epoch 5:  95%|█████████▍| 177/187 [7:54:09<09:19, 55.94s/it, training_loss=0.067]
# Epoch 5:  95%|█████████▌| 178/187 [7:55:05<08:24, 56.00s/it, training_loss=0.100]
# Epoch 5:  96%|█████████▌| 179/187 [7:56:01<07:26, 55.86s/it, training_loss=0.051]
# Epoch 5:  96%|█████████▋| 180/187 [7:56:56<06:30, 55.85s/it, training_loss=0.066]
# Epoch 5:  97%|█████████▋| 181/187 [7:57:52<05:35, 55.90s/it, training_loss=0.086]
# Epoch 5:  97%|█████████▋| 182/187 [7:58:48<04:39, 55.83s/it, training_loss=0.092]
# Epoch 5:  98%|█████████▊| 183/187 [7:59:43<03:42, 55.70s/it, training_loss=0.131]
# Epoch 5:  98%|█████████▊| 184/187 [8:00:39<02:46, 55.61s/it, training_loss=0.136]
# Epoch 5:  99%|█████████▉| 185/187 [8:01:35<01:51, 55.69s/it, training_loss=0.085]
# Epoch 5:  99%|█████████▉| 186/187 [8:02:30<00:55, 55.66s/it, training_loss=0.123]
# Epoch 5: 100%|██████████| 187/187 [8:02:50<00:00, 44.74s/it, training_loss=0.028]
#  80%|████████  | 4/5 [20:53:17<3:09:23, 11363.80s/it]
# Epoch 5
# Training loss: 0.27252744488856373
# 100%|██████████| 5/5 [21:21:41<00:00, 15380.36s/it]
# Validation loss: 0.32584634137914537
# F1 Score (Weighted): 0.9195400462068966
# ------

# %%
model = BertForSequenceClassification.from_pretrained("cl-tohoku/bert-base-japanese-v2",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)

model.to(device)
# Out:
# Some weights of the model checkpoint at cl-tohoku/bert-base-japanese-v2 were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cl-tohoku/bert-base-japanese-v2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(32768, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=13, bias=True)
# )

# %%
model.load_state_dict(torch.load('data_volume/finetuned_BERT_epoch_5.model', map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
_, predictions, true_vals = evaluate(dataloader_validation)

# %%
accuracy_per_class(predictions, true_vals)
# Out:
# Class: ドキュメンタリー/教養
# Accuracy: 175/202
#
# Class: 福祉
# Accuracy: 0/12
#
# Class: 音楽
# Accuracy: 131/141
#
# Class: ニュース/報道
# Accuracy: 446/447
#
# Class: ドラマ
# Accuracy: 45/49
#
# Class: 情報/ワイドショー
# Accuracy: 85/88
#
# Class: バラエティ
# Accuracy: 29/45
#
# Class: スポーツ
# Accuracy: 47/59
#
# Class: 趣味/教育
# Accuracy: 375/386
#
# Class: 劇場・公演
# Accuracy: 0/5
#
# Class: アニメ/特撮
# Accuracy: 25/31
#
# Class: その他
# Accuracy: 23/23
#
# Class: 映画
# Accuracy: 0/3
